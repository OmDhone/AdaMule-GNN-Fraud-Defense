# %% [markdown]
# # Notebook 05: Robustness Results & Comparative Benchmark
#
# Load benchmark comparison tables and visualize Clean vs. Adversarial Recall, Hard-Negative FPR, and Ablation Study.

# %%
import sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

root = Path.cwd().parent
csv_path = root / "outputs" / "reports" / "benchmark_comparison.csv"
if csv_path.exists():
    df = pd.read_csv(csv_path)
    display(df)

fig_path = root / "outputs" / "figures" / "clean_vs_adversarial_recall.png"
if fig_path.exists():
    img = mpimg.imread(str(fig_path))
    plt.figure(figsize=(10, 6))
    plt.imshow(img)
    plt.axis('off')
    plt.show()
